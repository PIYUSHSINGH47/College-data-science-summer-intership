# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stt
import seaborn as sns

# %%
data=pd.read_csv('Heart_Disease_Prediction.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      270 non-null    int64
#  2   Chest pain type          270 non-null    int64
#  3   BP                       270 non-null    int64
#  4   Cholesterol              270 non-null    int64
#  5   FBS over 120             270 non-null    int64
#  6   EKG results              270 non-null    int64
#  7   Max HR                   270 non-null    int64
#  8   Exercise angina          270 non-null    int64
#  9   ST depression            270 non-null    float64
#  10  Slope of ST              270 non-null    int64
#  11  Number of vessels fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
#  13  Heart Disease            270 non-null    object
# ...

# %%
data
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %% [markdown]
# This data tells about the people having age between 40 to 60 almost having high cholestereol and the people having age between the 60 to 70 having highest cholesterol i.e., greater than 500.

# %%
data.plot(kind='scatter',x='Age',y='Cholesterol')
# Out:
# <Axes: xlabel='Age', ylabel='Cholesterol'>

# %% [markdown]
# This data tells about the people having age between 40 to 70 almost having high BP and the people having age between the 50 to 60 having highest BP 200.

# %%
data.plot(kind='scatter',x='Age',y='BP')
# Out:
# <Axes: xlabel='Age', ylabel='BP'>

# %%
data['Chest pain type'].value_counts()
# Out:
# Chest pain type
# 4    129
# 3     79
# 2     42
# 1     20
# Name: count, dtype: int64

# %%
data2 = pd.read_csv('Heart_Disease_Prediction.csv')
data2.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %%
data2=data2.drop(["Heart Disease"],axis =1 )
cormat = data2.corr()
round(cormat,2)
# Out:
#                           Age   Sex  Chest pain type    BP  Cholesterol  \
# Age                      1.00 -0.09             0.10  0.27         0.22
# Sex                     -0.09  1.00             0.03 -0.06        -0.20
# Chest pain type          0.10  0.03             1.00 -0.04         0.09
# BP                       0.27 -0.06            -0.04  1.00         0.17
# Cholesterol              0.22 -0.20             0.09  0.17         1.00
# FBS over 120             0.12  0.04            -0.10  0.16         0.03
# EKG results              0.13  0.04             0.07  0.12         0.17
# Max HR                  -0.40 -0.08            -0.32 -0.04        -0.02
# Exercise angina          0.10  0.18             0.35  0.08         0.08
# ST depression            0.19  0.10             0.17  0.22         0.03
# Slope of ST              0.16  0.05             0.14  0.14        -0.01
# Number of vessels fluro  0.36  0.09             0.23  0.09         0.13
# ...

# %%
sns.heatmap(cormat)
# Out:
# <Axes: >
